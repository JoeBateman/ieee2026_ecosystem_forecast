# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
test_X = np.load('data/data_global/glob_X_fea.npy')
test_Y = np.load('data/data_global/glob_Y020.npy')

# %%
test_X.shape, test_Y.shape
# Out:
# ((54152, 40, 12, 136), (54152, 41, 12, 7))
